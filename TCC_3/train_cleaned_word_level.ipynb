# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

# Install a Drive FUSE wrapper.
# https://github.com/astrada/google-drive-ocamlfuse
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

# Generate auth tokens for Colab
from google.colab import auth
auth.authenticate_user()

# Generate creds for the Drive FUSE library.
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# Work around misordering of STREAM and STDIN in Jupyter.
# https://github.com/jupyter/notebook/issues/3159
prompt = !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass(prompt[0] + '\n\nEnter verification code: ')
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# Create a directory and mount Google Drive using that directory.
# !mkdir -p drive
# !google-drive-ocamlfuse drive

print('Files in Drive:')
# !ls drive/
# Out:
# Found GPU at: /device:GPU:0
# E: Package 'python-software-properties' has no installation candidate
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-6caa5adff360> in <module>()
#      24 # https://github.com/jupyter/notebook/issues/3159
#      25 prompt = get_ipython().getoutput('google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL')
# ---> 26 vcode = getpass.getpass(prompt[0] + '\n\nEnter verification code: ')
#      27 get_ipython().system('echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}')
#      28
#
# IndexError: list index out of range

# %%
cd drive/Study/finalYrProject/TCC_3/

# %%
########################################
## import packages
########################################
import os
import re
import csv
import codecs
import numpy as np
import pandas as pd
import operator
import sys

from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from string import punctuation
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

import toxic_m.models.keras.model_set as model_set
from toxic_m.train import trainer
from toxic_m.data_helper.data_loader import DataLoader
# Out:
# Using TensorFlow backend.

# %%
path = 'Dataset/'
EMBEDDING_FILE='features/crawl-300d-2M.vec'
#EMBEDDING_FILE='features/glove.840B.300d.txt'
#EMBEDDING_FILE='features/glove.twitter.27B.200d.txt'
TRAIN_DATA_FILE=path + 'cleaned_train.csv'
TEST_DATA_FILE=path + 'cleaned_test.csv'

MAX_SEQUENCE_LENGTH = 400
MAX_NB_WORDS = 100000
EMBEDDING_DIM = 300

# %%
train_df = pd.read_csv(TRAIN_DATA_FILE)
test_df = pd.read_csv(TEST_DATA_FILE)
data_loader = DataLoader()
embeddings_index = data_loader.load_embedding(EMBEDDING_FILE)
# Out:
# Total 2000000 word vectors.

# %%
########################################
## process texts in datasets
########################################
print('Processing text dataset')
list_sentences_train = train_df["comment_text"].fillna("no comment").values
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
y = train_df[list_classes].values
list_sentences_test = test_df["comment_text"].fillna("no comment").values

comments = []
for text in list_sentences_train:
    comments.append(text)
    
test_comments=[]
for text in list_sentences_test:
    test_comments.append(text)

#tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='"#%&()+,-./:;<=>@[\\]^_`{|}~\t\n')
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)

tokenizer.fit_on_texts(comments + test_comments)

sequences = tokenizer.texts_to_sequences(comments)
test_sequences = tokenizer.texts_to_sequences(test_comments)

word_index = tokenizer.word_index
print('Found %s unique tokens' % len(word_index))

data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', y.shape)

test_data = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of test_data tensor:', test_data.shape)
# Out:
# Processing text dataset
# Found 332116 unique tokens
# Shape of data tensor: (159571, 400)
# Shape of label tensor: (159571, 6)
# Shape of test_data tensor: (153164, 400)

# %%
########################################
## prepare embeddings
########################################
print('Preparing embedding matrix')
nb_words = min(MAX_NB_WORDS, len(word_index))
#embedding_matrix = np.random.normal(loc=matrix_mean, scale=matrix_std, size=(nb_words, EMBEDDING_DIM))
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
null_count = 0
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        null_count += 1
print('Null word embeddings: %d' % null_count)
# Out:
# Preparing embedding matrix
# Null word embeddings: 24105

# %%
def get_model():
    return model_zoo.get_rcnn(nb_words, EMBEDDING_DIM, embedding_matrix, MAX_SEQUENCE_LENGTH, out_size=6)

keras_model_trainer = trainer.KerasModelTrainer(model_stamp='rcnn', epoch_num=8, learning_rate=1e-3)

# %%
models, val_loss, total_auc, fold_predictions = keras_model_trainer.train_folds(data, y, fold_count=5, batch_size=256, get_model_func=get_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 400)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 400, 300)     30000000    input_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 400, 300)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 400, 128)     140544      spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 399, 128)     32896       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# attention_weighted_average_1 (A (None, 128)          128         conv1d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 384)          0           global_max_pooling1d_1[0][0]
#                                                                  attention_weighted_average_1[0][0
#                                                                  global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 384)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 120)          46200       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6)            726         dense_1[0][0]
# ==================================================================================================
# Total params: 30,220,494
# Trainable params: 220,494
# Non-trainable params: 30,000,000
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/8
# 127657/127657 [==============================] - 120s 937us/step - loss: 0.0703 - acc: 0.9765 - val_loss: 0.0459 - val_acc: 0.9823
# Epoch 2/8
# 127657/127657 [==============================] - 115s 904us/step - loss: 0.0475 - acc: 0.9823 - val_loss: 0.0439 - val_acc: 0.9827
# Epoch 3/8
# 127657/127657 [==============================] - 116s 909us/step - loss: 0.0444 - acc: 0.9831 - val_loss: 0.0411 - val_acc: 0.9837
# Epoch 4/8
# 127657/127657 [==============================] - 116s 906us/step - loss: 0.0425 - acc: 0.9836 - val_loss: 0.0403 - val_acc: 0.9841
# Epoch 5/8
# 127657/127657 [==============================] - 116s 905us/step - loss: 0.0409 - acc: 0.9840 - val_loss: 0.0400 - val_acc: 0.9840
# Epoch 6/8
# 127657/127657 [==============================] - 116s 905us/step - loss: 0.0395 - acc: 0.9846 - val_loss: 0.0392 - val_acc: 0.9844
# Epoch 7/8
# 127657/127657 [==============================] - 115s 903us/step - loss: 0.0384 - acc: 0.9849 - val_loss: 0.0394 - val_acc: 0.9843
# Epoch 8/8
# 127657/127657 [==============================] - 116s 905us/step - loss: 0.0371 - acc: 0.9853 - val_loss: 0.0399 - val_acc: 0.9839
# AUC Score 0.9891254001246255
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 400)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 400, 300)     30000000    input_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 400, 300)     0           embedding_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 400, 128)     140544      spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 399, 128)     32896       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 128)          0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# attention_weighted_average_2 (A (None, 128)          128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 128)          0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 384)          0           global_max_pooling1d_2[0][0]
#                                                                  attention_weighted_average_2[0][0
#                                                                  global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 384)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 120)          46200       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 6)            726         dense_3[0][0]
# ==================================================================================================
# Total params: 30,220,494
# Trainable params: 220,494
# Non-trainable params: 30,000,000
# __________________________________________________________________________________________________
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/8
# 127657/127657 [==============================] - 117s 915us/step - loss: 0.0717 - acc: 0.9763 - val_loss: 0.0485 - val_acc: 0.9818
# Epoch 2/8
# 127657/127657 [==============================] - 116s 906us/step - loss: 0.0474 - acc: 0.9820 - val_loss: 0.0452 - val_acc: 0.9831
# Epoch 3/8
# 127657/127657 [==============================] - 116s 908us/step - loss: 0.0445 - acc: 0.9828 - val_loss: 0.0418 - val_acc: 0.9840
# Epoch 4/8
# 127657/127657 [==============================] - 116s 907us/step - loss: 0.0421 - acc: 0.9836 - val_loss: 0.0410 - val_acc: 0.9840
# Epoch 5/8
# 127657/127657 [==============================] - 115s 904us/step - loss: 0.0408 - acc: 0.9839 - val_loss: 0.0403 - val_acc: 0.9840
# Epoch 6/8
# 127657/127657 [==============================] - 116s 909us/step - loss: 0.0392 - acc: 0.9845 - val_loss: 0.0396 - val_acc: 0.9845
# Epoch 7/8
# 127657/127657 [==============================] - 115s 904us/step - loss: 0.0382 - acc: 0.9849 - val_loss: 0.0401 - val_acc: 0.9846
# Epoch 8/8
# 127657/127657 [==============================] - 116s 907us/step - loss: 0.0374 - acc: 0.9851 - val_loss: 0.0394 - val_acc: 0.9844
# AUC Score 0.9887844944708551
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 400)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 400, 300)     30000000    input_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 400, 300)     0           embedding_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 400, 128)     140544      spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 399, 128)     32896       bidirectional_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 128)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# attention_weighted_average_3 (A (None, 128)          128         conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 128)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 384)          0           global_max_pooling1d_3[0][0]
#                                                                  attention_weighted_average_3[0][0
#                                                                  global_average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 384)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 120)          46200       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 6)            726         dense_5[0][0]
# ==================================================================================================
# Total params: 30,220,494
# Trainable params: 220,494
# Non-trainable params: 30,000,000
# __________________________________________________________________________________________________
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/8
# 127657/127657 [==============================] - 117s 913us/step - loss: 0.0722 - acc: 0.9765 - val_loss: 0.0449 - val_acc: 0.9826
# Epoch 2/8
# 127657/127657 [==============================] - 115s 900us/step - loss: 0.0478 - acc: 0.9820 - val_loss: 0.0424 - val_acc: 0.9836
# Epoch 3/8
# 127657/127657 [==============================] - 115s 902us/step - loss: 0.0448 - acc: 0.9827 - val_loss: 0.0401 - val_acc: 0.9844
# Epoch 4/8
# 127657/127657 [==============================] - 115s 902us/step - loss: 0.0425 - acc: 0.9834 - val_loss: 0.0411 - val_acc: 0.9834
# Epoch 5/8
# 127657/127657 [==============================] - 116s 910us/step - loss: 0.0410 - acc: 0.9837 - val_loss: 0.0393 - val_acc: 0.9851
# Epoch 6/8
# 127657/127657 [==============================] - 115s 904us/step - loss: 0.0401 - acc: 0.9841 - val_loss: 0.0381 - val_acc: 0.9850
# Epoch 7/8
# 127657/127657 [==============================] - 116s 907us/step - loss: 0.0385 - acc: 0.9846 - val_loss: 0.0377 - val_acc: 0.9851
# Epoch 8/8
# 127657/127657 [==============================] - 116s 908us/step - loss: 0.0379 - acc: 0.9849 - val_loss: 0.0379 - val_acc: 0.9848
# AUC Score 0.9903514935497267
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 400)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 400, 300)     30000000    input_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 400, 300)     0           embedding_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 400, 128)     140544      spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 399, 128)     32896       bidirectional_4[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_4 (GlobalM (None, 128)          0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# attention_weighted_average_4 (A (None, 128)          128         conv1d_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 128)          0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 384)          0           global_max_pooling1d_4[0][0]
#                                                                  attention_weighted_average_4[0][0
#                                                                  global_average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 384)          0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 120)          46200       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 6)            726         dense_7[0][0]
# ==================================================================================================
# Total params: 30,220,494
# Trainable params: 220,494
# Non-trainable params: 30,000,000
# __________________________________________________________________________________________________
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/8
# 127657/127657 [==============================] - 117s 916us/step - loss: 0.0699 - acc: 0.9769 - val_loss: 0.0459 - val_acc: 0.9826
# Epoch 2/8
# 127657/127657 [==============================] - 115s 900us/step - loss: 0.0481 - acc: 0.9818 - val_loss: 0.0436 - val_acc: 0.9834
# Epoch 3/8
# 127657/127657 [==============================] - 115s 905us/step - loss: 0.0447 - acc: 0.9828 - val_loss: 0.0426 - val_acc: 0.9835
# Epoch 4/8
# 127657/127657 [==============================] - 115s 902us/step - loss: 0.0423 - acc: 0.9835 - val_loss: 0.0410 - val_acc: 0.9841
# Epoch 5/8
# 127657/127657 [==============================] - 116s 906us/step - loss: 0.0408 - acc: 0.9840 - val_loss: 0.0397 - val_acc: 0.9841
# Epoch 6/8
# 127657/127657 [==============================] - 115s 904us/step - loss: 0.0396 - acc: 0.9844 - val_loss: 0.0398 - val_acc: 0.9841
# Epoch 7/8
# 127657/127657 [==============================] - 115s 901us/step - loss: 0.0383 - acc: 0.9849 - val_loss: 0.0394 - val_acc: 0.9844
# Epoch 8/8
# 127657/127657 [==============================] - 115s 903us/step - loss: 0.0371 - acc: 0.9852 - val_loss: 0.0394 - val_acc: 0.9844
# AUC Score 0.9881152303601489
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 400)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 400, 300)     30000000    input_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 400, 300)     0           embedding_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 400, 128)     140544      spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 399, 128)     32896       bidirectional_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 128)          0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# attention_weighted_average_5 (A (None, 128)          128         conv1d_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_5 (Glo (None, 128)          0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 384)          0           global_max_pooling1d_5[0][0]
#                                                                  attention_weighted_average_5[0][0
#                                                                  global_average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 384)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 120)          46200       dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 6)            726         dense_9[0][0]
# ==================================================================================================
# Total params: 30,220,494
# Trainable params: 220,494
# Non-trainable params: 30,000,000
# __________________________________________________________________________________________________
# Train on 127656 samples, validate on 31915 samples
# Epoch 1/8
# 127656/127656 [==============================] - 117s 918us/step - loss: 0.0716 - acc: 0.9765 - val_loss: 0.0473 - val_acc: 0.9825
# Epoch 2/8
# 127656/127656 [==============================] - 117s 913us/step - loss: 0.0474 - acc: 0.9822 - val_loss: 0.0446 - val_acc: 0.9832
# Epoch 3/8
# 127656/127656 [==============================] - 116s 907us/step - loss: 0.0444 - acc: 0.9829 - val_loss: 0.0415 - val_acc: 0.9840
# Epoch 4/8
# 127656/127656 [==============================] - 116s 905us/step - loss: 0.0423 - acc: 0.9834 - val_loss: 0.0412 - val_acc: 0.9840
# Epoch 5/8
# 127656/127656 [==============================] - 116s 906us/step - loss: 0.0408 - acc: 0.9839 - val_loss: 0.0403 - val_acc: 0.9842
# Epoch 6/8
# 127656/127656 [==============================] - 116s 909us/step - loss: 0.0394 - acc: 0.9843 - val_loss: 0.0400 - val_acc: 0.9844
# Epoch 7/8
# 127656/127656 [==============================] - 116s 906us/step - loss: 0.0383 - acc: 0.9848 - val_loss: 0.0407 - val_acc: 0.9841
# Epoch 8/8
# 127656/127656 [==============================] - 115s 901us/step - loss: 0.0371 - acc: 0.9852 - val_loss: 0.0396 - val_acc: 0.9848
# AUC Score 0.9881839390281225

# %%
print("Overall val-loss:", val_loss, "AUC", total_auc)
# Out:
# Overall val-loss: 0.03905138458915143 AUC 0.9889121115066958

# %% [markdown]
# ## Predections

# %%
train_fold_preditcions = np.concatenate(fold_predictions, axis=0)

# %%
from sklearn.metrics import roc_auc_score
training_auc = roc_auc_score(y[:], train_fold_preditcions)
print("Training AUC", training_auc)
# Out:
# Training AUC 0.98854331678751

# %%
#test_data = test_df
CLASSES = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
submit_path_prefix = "predict_path"

print("Predicting testing results...")
test_predicts_list = []
for fold_id, model in enumerate(models):
    test_predicts = model.predict(test_data, batch_size=256, verbose=1)
    test_predicts_list.append(test_predicts)
    np.save("predict_path/", test_predicts)

test_predicts = np.zeros(test_predicts_list[0].shape)
for fold_predict in test_predicts_list:
    test_predicts += fold_predict
test_predicts /= len(test_predicts_list)

test_ids = test_df["id"].values
test_ids = test_ids.reshape((len(test_ids), 1))

test_predicts = pd.DataFrame(data=test_predicts, columns=CLASSES)
test_predicts["id"] = test_ids
test_predicts = test_predicts[["id"] + CLASSES]
submit_path = submit_path_prefix + "-L{:4f}-A{:4f}.csv".format(val_loss, total_auc)
test_predicts.to_csv(submit_path, index=False)
# Out:
# Predicting testing results...
# 153164/153164 [==============================] - 46s 299us/step
# 153164/153164 [==============================] - 46s 302us/step
# 153164/153164 [==============================] - 46s 299us/step
# 153164/153164 [==============================] - 46s 303us/step
# 153164/153164 [==============================] - 46s 303us/step

# %%
print("Predicting training results...")

train_ids = train_df["id"].values
train_ids = train_ids.reshape((len(train_ids), 1))

train_predicts = pd.DataFrame(data=train_fold_preditcions, columns=CLASSES)
train_predicts["id"] = train_ids
train_predicts = train_predicts[["id"] + CLASSES]
submit_path = submit_path_prefix + "-Train-L{:4f}-A{:4f}.csv".format(val_loss, training_auc)
train_predicts.to_csv(submit_path, index=False)
# Out:
# Predicting training results...
